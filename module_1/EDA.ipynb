# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from ydata_profiling import ProfileReport
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Загрузка данных и первичный анализ

# %%
df = pd.read_csv('data/game_awards_nominees.csv')

# %%
df.head()
# Out:
#    type                       name  steam_appid is_free controller_support  \
# 0  game             counter-strike           10   False                NaN
# 1  game      team fortress classic           20   False                NaN
# 2  game              day of defeat           30   False                NaN
# 3  game         deathmatch classic           40   False                NaN
# 4  game  half-life: opposing force           50   False                NaN
#
#    dlc                                  short_description  \
# 0  NaN  Play the world's number 1 online action game. ...
# 1  NaN  One of the most popular online action games of...
# 2  NaN  Enlist in an intense brand of Axis vs. Allied ...
# 3  NaN  Enjoy fast-paced multiplayer gaming with Death...
# 4  NaN  Return to the Black Mesa Research Facility as ...
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements            developers  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  ['Gearbox Software']
#
#   publishers                                     price_overview  \
# 0  ['Valve']  {'currency': 'AUD', 'initial': 1450, 'final': ...
# 1  ['Valve']  {'currency': 'AUD', 'initial': 750, 'final': 7...
# 2  ['Valve']  {'currency': 'AUD', 'initial': 750, 'final': 7...
# 3  ['Valve']  {'currency': 'AUD', 'initial': 750, 'final': 7...
# 4  ['Valve']  {'currency': 'AUD', 'initial': 750, 'final': 7...
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
# 1  {'windows': True, 'mac': True, 'linux': True}
# 2  {'windows': True, 'mac': True, 'linux': True}
# 3  {'windows': True, 'mac': True, 'linux': True}
# 4  {'windows': True, 'mac': True, 'linux': True}
#
#                                           metacritic  \
# 0  {'score': 88, 'url': 'https://www.metacritic.c...
# 1                                                NaN
# 2  {'score': 79, 'url': 'https://www.metacritic.c...
# 3                                                NaN
# 4                                                NaN
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                     release_date     award_name
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}  not nominated
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}  not nominated
# 2  {'coming_soon': False, 'date': '1 May, 2003'}  not nominated
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}  not nominated
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}  not nominated

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1072 entries, 0 to 1071
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   type                1066 non-null   object
#  1   name                1072 non-null   object
#  2   steam_appid         1072 non-null   int64
#  3   is_free             1066 non-null   object
#  4   controller_support  463 non-null    object
#  5   dlc                 607 non-null    object
#  6   short_description   1066 non-null   object
#  7   pc_requirements     1066 non-null   object
#  8   mac_requirements    1066 non-null   object
#  9   linux_requirements  1066 non-null   object
#  10  developers          1065 non-null   object
#  11  publishers          1066 non-null   object
#  12  price_overview      789 non-null    object
#  13  platforms           1066 non-null   object
#  14  metacritic          631 non-null    object
#  15  genres              1064 non-null   object
#  16  release_date        1066 non-null   object
#  17  award_name          1072 non-null   object
# dtypes: int64(1), object(17)
# memory usage: 150.9+ KB

# %% [markdown]
# ## Обработка пропусков и дубликатов, преобразование данных

# %%
df.isnull().sum()
# Out:
# type                    6
# name                    0
# steam_appid             0
# is_free                 6
# controller_support    609
# dlc                   465
# short_description       6
# pc_requirements         6
# mac_requirements        6
# linux_requirements      6
# developers              7
# publishers              6
# price_overview        283
# platforms               6
# metacritic            441
# genres                  8
# release_date            6
# award_name              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates()
# Out:
#       type                       name  steam_appid is_free controller_support  \
# 0     game             counter-strike           10   False                NaN
# 1     game      team fortress classic           20   False                NaN
# 2     game              day of defeat           30   False                NaN
# 3     game         deathmatch classic           40   False                NaN
# 4     game  half-life: opposing force           50   False                NaN
# ...    ...                        ...          ...     ...                ...
# 1067  game       inside the backrooms      1987080   False                NaN
# 1068  game            resident evil 4      2050650   False               full
# 1069  game            resident evil 4      2050650   False               full
# 1070  game            resident evil 4      2050650   False               full
# 1071  game            resident evil 4      2050650   False               full
#
#                                                     dlc  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1067                                                NaN
# 1068  [2109315, 2109301, 2109303, 2109304, 2109305, ...
# 1069  [2109315, 2109301, 2109303, 2109304, 2109305, ...
# 1070  [2109315, 2109301, 2109303, 2109304, 2109305, ...
# 1071  [2109315, 2109301, 2109303, 2109304, 2109305, ...
#
#                                       short_description  \
# 0     Play the world's number 1 online action game. ...
# 1     One of the most popular online action games of...
# 2     Enlist in an intense brand of Axis vs. Allied ...
# 3     Enjoy fast-paced multiplayer gaming with Death...
# 4     Return to the Black Mesa Research Facility as ...
# ...                                                 ...
# 1067  Inside the Backrooms is a horror multiplayer g...
# 1068  Survival is just the beginning. Six years have...
# 1069  Survival is just the beginning. Six years have...
# 1070  Survival is just the beginning. Six years have...
# 1071  Survival is just the beginning. Six years have...
#
#                                         pc_requirements  \
# 0     {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1     {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2     {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3     {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4     {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# ...                                                 ...
# 1067  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 1068  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 1069  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 1070  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 1071  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                        mac_requirements  \
# 0     {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1     {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2     {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3     {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4     {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# ...                                                 ...
# 1067  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 1068  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 1069  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 1070  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 1071  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                      linux_requirements            developers  \
# 0     {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 1     {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 2     {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 3     {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 4     {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  ['Gearbox Software']
# ...                                                 ...                   ...
# 1067  {'minimum': '<strong>Minimum:</strong><br><ul ...          ['MrFatcat']
# 1068  {'minimum': '<strong>Minimum:</strong><br><ul ...  ['CAPCOM Co., Ltd.']
# 1069  {'minimum': '<strong>Minimum:</strong><br><ul ...  ['CAPCOM Co., Ltd.']
# 1070  {'minimum': '<strong>Minimum:</strong><br><ul ...  ['CAPCOM Co., Ltd.']
# 1071  {'minimum': '<strong>Minimum:</strong><br><ul ...  ['CAPCOM Co., Ltd.']
#
#                      publishers  \
# 0                     ['Valve']
# 1                     ['Valve']
# 2                     ['Valve']
# 3                     ['Valve']
# 4                     ['Valve']
# ...                         ...
# 1067  ['MrFatcat', 'Dropsiick']
# 1068       ['CAPCOM Co., Ltd.']
# 1069       ['CAPCOM Co., Ltd.']
# 1070       ['CAPCOM Co., Ltd.']
# 1071       ['CAPCOM Co., Ltd.']
#
#                                          price_overview  \
# 0     {'currency': 'AUD', 'initial': 1450, 'final': ...
# 1     {'currency': 'AUD', 'initial': 750, 'final': 7...
# 2     {'currency': 'AUD', 'initial': 750, 'final': 7...
# 3     {'currency': 'AUD', 'initial': 750, 'final': 7...
# 4     {'currency': 'AUD', 'initial': 750, 'final': 7...
# ...                                                 ...
# 1067  {'currency': 'AUD', 'initial': 1000, 'final': ...
# 1068  {'currency': 'AUD', 'initial': 8549, 'final': ...
# 1069  {'currency': 'AUD', 'initial': 8549, 'final': ...
# 1070  {'currency': 'AUD', 'initial': 8549, 'final': ...
# 1071  {'currency': 'AUD', 'initial': 8549, 'final': ...
#
#                                             platforms  \
# 0       {'windows': True, 'mac': True, 'linux': True}
# 1       {'windows': True, 'mac': True, 'linux': True}
# 2       {'windows': True, 'mac': True, 'linux': True}
# 3       {'windows': True, 'mac': True, 'linux': True}
# 4       {'windows': True, 'mac': True, 'linux': True}
# ...                                               ...
# 1067  {'windows': True, 'mac': False, 'linux': False}
# 1068  {'windows': True, 'mac': False, 'linux': False}
# 1069  {'windows': True, 'mac': False, 'linux': False}
# 1070  {'windows': True, 'mac': False, 'linux': False}
# 1071  {'windows': True, 'mac': False, 'linux': False}
#
#                                              metacritic  \
# 0     {'score': 88, 'url': 'https://www.metacritic.c...
# 1                                                   NaN
# 2     {'score': 79, 'url': 'https://www.metacritic.c...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1067                                                NaN
# 1068                                                NaN
# 1069                                                NaN
# 1070                                                NaN
# 1071                                                NaN
#
#                                                  genres  \
# 0                [{'id': '1', 'description': 'Action'}]
# 1                [{'id': '1', 'description': 'Action'}]
# 2                [{'id': '1', 'description': 'Action'}]
# 3                [{'id': '1', 'description': 'Action'}]
# 4                [{'id': '1', 'description': 'Action'}]
# ...                                                 ...
# 1067  [{'id': '25', 'description': 'Adventure'}, {'i...
# 1068  [{'id': '1', 'description': 'Action'}, {'id': ...
# 1069  [{'id': '1', 'description': 'Action'}, {'id': ...
# 1070  [{'id': '1', 'description': 'Action'}, {'id': ...
# 1071  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                         release_date               award_name
# 0      {'coming_soon': False, 'date': '1 Nov, 2000'}            not nominated
# 1      {'coming_soon': False, 'date': '1 Apr, 1999'}            not nominated
# 2      {'coming_soon': False, 'date': '1 May, 2003'}            not nominated
# 3      {'coming_soon': False, 'date': '1 Jun, 2001'}            not nominated
# 4      {'coming_soon': False, 'date': '1 Nov, 1999'}            not nominated
# ...                                              ...                      ...
# 1067  {'coming_soon': False, 'date': '20 Jun, 2022'}            not nominated
# 1068  {'coming_soon': False, 'date': '23 Mar, 2023'}         Game of the Year
# 1069  {'coming_soon': False, 'date': '23 Mar, 2023'}        Best Audio Design
# 1070  {'coming_soon': False, 'date': '23 Mar, 2023'}             Best VR / AR
# 1071  {'coming_soon': False, 'date': '23 Mar, 2023'}  Best Action / Adventure
#
# [1071 rows x 18 columns]

# %%
df['price_overview'] = df['price_overview'].fillna("{'final': '0'}")
df['price_overview'] = df['price_overview'].apply(lambda x: float(ast.literal_eval(x)['final'])/100)

df['metacritic'] = df['metacritic'].fillna("{'score': '0'}")
df['metacritic'] = df['metacritic'].apply(lambda x: float(ast.literal_eval(x)['score']))

# %%
df['genres'] = df['genres'].fillna("[{'id': '0', 'description': 'Unknown'}]")

# %%
problematic_columns = ['type', 'controller_support', 'dlc', 'short_description', 'award_name']
df[problematic_columns] = df[problematic_columns].fillna('Unknown')


df.isnull().sum()
# Out:
# type                  0
# name                  0
# steam_appid           0
# is_free               6
# controller_support    0
# dlc                   0
# short_description     0
# pc_requirements       6
# mac_requirements      6
# linux_requirements    6
# developers            7
# publishers            6
# price_overview        0
# platforms             6
# metacritic            0
# genres                0
# release_date          6
# award_name            0
# dtype: int64

# %%
df = df.dropna()

# %%
df['genres'] = df['genres'].apply(ast.literal_eval)

# %%
df['genre_id'] = df['genres'].apply(lambda x: [item['id'] for item in x] if x else ['0'])
df['genre'] = df['genres'].apply(lambda x: [item['description'] for item in x] if x else ['Unknown'])

# %%
df = df.explode('genre_id')

# %%
df = df.explode('genre')

# %%
df['release_date'] = df['release_date'].apply(lambda x: x['date'] if isinstance(x, dict) and 'date' in x else x)

# %% [markdown]
# ## Делаем часть разведывательного анализа с помощью ydata_profiling

# %%
profile = ProfileReport(df, title='Profile Report')
profile.to_file("output.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Гистограмма распределения оценок Metacritic

# %%
# %matplotlib inline

# %%
has_metacritic = df[df['metacritic'] > 0]

plt.figure(figsize=(15, 6))
sns.histplot(x=has_metacritic['metacritic'], kde=True, bins=10, edgecolor='black', palette='viridis', multiple="layer")
plt.xlabel('Metacritic Score')
plt.ylabel('Frequency')
plt.title('Distribution of metacritic score', size = 24)
plt.show()

# %% [markdown]
# ## Топ-5 игр по оценкам Metacritic

# %%
top_5_critics = has_metacritic.nlargest(5, 'metacritic')

plt.figure(figsize = (15,6))
average_score_by_genre = top_10_critics.groupby('name')['metacritic'].mean().sort_values(ascending=False)
sns.barplot(x = average_score_by_genre.index, y = average_score_by_genre)
plt.xticks(rotation=45)

for index, value in enumerate(average_score_by_genre):
    plt.text(index, value, str(round(value, 2)), ha='center', va='bottom', fontweight = 'bold')
plt.xlabel('Game')
plt.ylabel('Metacritic Score')
plt.tight_layout()
plt.title('Critically acclaimed games', size = 24)
plt.show()

# %% [markdown]
# ## Гистограмма распределения цен

# %%
plt.figure(figsize=(15, 6))
sns.histplot(x = df['price_overview'], bins = 25, edgecolor = 'black', palette = None, kde = True)
plt.xlabel('Price Overview')
plt.ylabel('Frequency')
plt.title('Price Distribution', size = 24)
plt.show()

# %% [markdown]
# ## Тепловая карта корреляции числовых и бинарных признаков

# %%
df['platforms'] = df['platforms'].apply(ast.literal_eval)

df['windows'] = df['platforms'].apply(lambda x: x.get('windows', False))
df['mac'] = df['platforms'].apply(lambda x: x.get('mac', False))
df['linux'] = df['platforms'].apply(lambda x: x.get('linux', False))

numeric_features = ['is_free', 'metacritic', 'price_overview', 'mac', 'linux']

plt.figure(figsize=(10, 8))
sns.heatmap(df[numeric_features].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Как эти данные могут быть использованы в целях машинного обучения:
#
# ### 1) Прогнозирование цен на игры:
# Используя информацию о характеристиках игр (например, платформы, жанры, разработчики), можно попытаться построить модель для прогнозирования цен на игры.
#
# ### 2) Классификация игр:
# На основе информации о жанрах, платформах и других характеристиках можно создать модель классификации, которая определяет, к какой категории или жанру относится игра.
#
# ### 3) Прогнозирование оценок Metacritic:
# Используя данные о характеристиках игр, можно попытаться создать модель, предсказывающую оценки Metacritic.
#
# ### 4) Анализ трендов в игровой индустрии:
# Используя информацию о датах релиза и жанрах, можно провести анализ трендов в игровой индустрии, определяя, какие жанры популярны в разные периоды времени.
#
# ### 5) Кластеризация игр:
# Применение методов кластеризации к данным о характеристиках игр может помочь выявить группы схожих игр, что может быть полезно для персонализации рекомендаций.
#
# ### 6) Определение факторов успеха игр:
# Используя различные характеристики игр, можно попытаться выделить факторы, влияющие на их успех.
#
# ### 7) Предсказать критерии номинирования на The Game Awards и, возможно, победителей:
# Если дополнить датасет данными прошлых лет, то можно и попробовать))
